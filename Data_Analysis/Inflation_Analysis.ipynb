# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.options.display.float_format = '{:.8f}'.format

# %%
data = pd.read_csv('C:\PytonDataSets\Global Dataset of Inflation.csv', encoding='cp1252')
data.head()
# Out:
#   Country Code  IMF Country Code               Country Indicator Type  \
# 0          ABW      314.00000000                 Aruba      Inflation
# 1          AFG      512.00000000           Afghanistan      Inflation
# 2          AGO      614.00000000                Angola      Inflation
# 3          ALB      914.00000000               Albania      Inflation
# 4          ARE      466.00000000  United Arab Emirates      Inflation
#
#                          Series Name        1970        1971         1972  \
# 0  Headline Consumer Price Inflation         NaN         NaN          NaN
# 1  Headline Consumer Price Inflation 25.51000000 25.51000000 -12.52000000
# 2  Headline Consumer Price Inflation  7.97000000  5.78000000  15.80000000
# 3  Headline Consumer Price Inflation         NaN         NaN          NaN
# 4  Headline Consumer Price Inflation 21.98000000 21.98000000  21.98000000
#
#           1973        1974  ...        2019        2020        2021  \
# 0          NaN         NaN  ...  4.26000000  1.22000000  0.74000000
# 1 -10.68000000 10.23000000  ...  2.30000000  5.44000000  5.06000000
# 2  15.67000000 27.42000000  ... 17.08000000 21.02000000 23.85000000
# 3          NaN         NaN  ...  1.41000000  1.62000000  2.04000000
# 4  21.98000000 21.98000000  ... -1.93000000 -2.08000000  0.18000000
#
#          2022                      Note  Unnamed: 59  Unnamed: 60  \
# 0  6.04000000  Annual average inflation          NaN          NaN
# 1         NaN  Annual average inflation          NaN          NaN
# 2 21.35000000  Annual average inflation          NaN          NaN
# 3  6.73000000  Annual average inflation          NaN          NaN
# 4  5.22000000  Annual average inflation          NaN          NaN
#
#    Unnamed: 61  Unnamed: 62  Unnamed: 63
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN
# 3          NaN          NaN          NaN
# 4          NaN          NaN          NaN
#
# [5 rows x 64 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 783 entries, 0 to 782
# Data columns (total 64 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country Code      783 non-null    object
#  1   IMF Country Code  781 non-null    float64
#  2   Country           783 non-null    object
#  3   Indicator Type    783 non-null    object
#  4   Series Name       783 non-null    object
#  5   1970              422 non-null    float64
#  6   1971              428 non-null    float64
#  7   1972              430 non-null    float64
#  8   1973              430 non-null    float64
#  9   1974              434 non-null    float64
#  10  1975              434 non-null    float64
#  11  1976              430 non-null    float64
#  12  1977              427 non-null    float64
#  13  1978              428 non-null    float64
#  14  1979              428 non-null    float64
#  15  1980              433 non-null    float64
#  16  1981              451 non-null    float64
#  17  1982              458 non-null    float64
#  18  1983              464 non-null    float64
#  19  1984              470 non-null    float64
#  20  1985              466 non-null    float64
#  21  1986              475 non-null    float64
#  22  1987              482 non-null    float64
#  23  1988              485 non-null    float64
#  24  1989              483 non-null    float64
#  25  1990              489 non-null    float64
#  26  1991              507 non-null    float64
#  27  1992              519 non-null    float64
#  28  1993              536 non-null    float64
#  29  1994              552 non-null    float64
#  30  1995              559 non-null    float64
#  31  1996              570 non-null    float64
#  32  1997              575 non-null    float64
#  33  1998              584 non-null    float64
#  34  1999              591 non-null    float64
#  35  2000              596 non-null    float64
#  36  2001              610 non-null    float64
#  37  2002              625 non-null    float64
#  38  2003              629 non-null    float64
#  39  2004              634 non-null    float64
#  40  2005              646 non-null    float64
#  41  2006              661 non-null    float64
#  42  2007              671 non-null    float64
#  43  2008              680 non-null    float64
#  44  2009              686 non-null    float64
#  45  2010              693 non-null    float64
#  46  2011              687 non-null    float64
#  47  2012              696 non-null    float64
#  48  2013              715 non-null    float64
#  49  2014              734 non-null    float64
#  50  2015              735 non-null    float64
#  51  2016              746 non-null    float64
#  52  2017              737 non-null    float64
#  53  2018              737 non-null    float64
#  54  2019              728 non-null    float64
#  55  2020              719 non-null    float64
#  56  2021              706 non-null    float64
#  57  2022              665 non-null    float64
#  58  Note              783 non-null    object
#  59  Unnamed: 59       19 non-null     object
#  60  Unnamed: 60       0 non-null      float64
#  61  Unnamed: 61       0 non-null      float64
#  62  Unnamed: 62       0 non-null      float64
#  63  Unnamed: 63       0 non-null      float64
# dtypes: float64(58), object(6)
# memory usage: 391.6+ KB

# %%
data = data.drop(data.columns[-5:], axis=1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 783 entries, 0 to 782
# Data columns (total 59 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country Code      783 non-null    object
#  1   IMF Country Code  781 non-null    float64
#  2   Country           783 non-null    object
#  3   Indicator Type    783 non-null    object
#  4   Series Name       783 non-null    object
#  5   1970              422 non-null    float64
#  6   1971              428 non-null    float64
#  7   1972              430 non-null    float64
#  8   1973              430 non-null    float64
#  9   1974              434 non-null    float64
#  10  1975              434 non-null    float64
#  11  1976              430 non-null    float64
#  12  1977              427 non-null    float64
#  13  1978              428 non-null    float64
#  14  1979              428 non-null    float64
#  15  1980              433 non-null    float64
#  16  1981              451 non-null    float64
#  17  1982              458 non-null    float64
#  18  1983              464 non-null    float64
#  19  1984              470 non-null    float64
#  20  1985              466 non-null    float64
#  21  1986              475 non-null    float64
#  22  1987              482 non-null    float64
#  23  1988              485 non-null    float64
#  24  1989              483 non-null    float64
#  25  1990              489 non-null    float64
#  26  1991              507 non-null    float64
#  27  1992              519 non-null    float64
#  28  1993              536 non-null    float64
#  29  1994              552 non-null    float64
#  30  1995              559 non-null    float64
#  31  1996              570 non-null    float64
#  32  1997              575 non-null    float64
#  33  1998              584 non-null    float64
#  34  1999              591 non-null    float64
#  35  2000              596 non-null    float64
#  36  2001              610 non-null    float64
#  37  2002              625 non-null    float64
#  38  2003              629 non-null    float64
#  39  2004              634 non-null    float64
#  40  2005              646 non-null    float64
#  41  2006              661 non-null    float64
#  42  2007              671 non-null    float64
#  43  2008              680 non-null    float64
#  44  2009              686 non-null    float64
#  45  2010              693 non-null    float64
#  46  2011              687 non-null    float64
#  47  2012              696 non-null    float64
#  48  2013              715 non-null    float64
#  49  2014              734 non-null    float64
#  50  2015              735 non-null    float64
#  51  2016              746 non-null    float64
#  52  2017              737 non-null    float64
#  53  2018              737 non-null    float64
#  54  2019              728 non-null    float64
#  55  2020              719 non-null    float64
#  56  2021              706 non-null    float64
#  57  2022              665 non-null    float64
#  58  Note              783 non-null    object
# dtypes: float64(54), object(5)
# memory usage: 361.0+ KB

# %%
data = data.drop(['IMF Country Code', 'Indicator Type', 'Note', 'Series Name'], axis=1)

# %%
data = data.drop_duplicates(subset=['Country']).reset_index()
data = data.drop_duplicates(subset=['Country Code']).reset_index()

# %%
data.set_index('Country', inplace=True)

# %%
data = data.drop(data.columns[0], axis=1)
data
# Out:
#                           index Country Code        1970        1971  \
# Country
# Aruba                         0          ABW         NaN         NaN
# Afghanistan                   1          AFG 25.51000000 25.51000000
# Angola                        2          AGO  7.97000000  5.78000000
# Albania                       3          ALB         NaN         NaN
# United Arab Emirates          4          ARE 21.98000000 21.98000000
# ...                         ...          ...         ...         ...
# Saint Helena                200          SHN         NaN         NaN
# Timor-Leste                 201          TLS         NaN         NaN
# Turks and Caicos Islands    202          TCA         NaN         NaN
# Somalia                     648          SOM         NaN         NaN
# Taiwan, China               661          TWN         NaN         NaN
#
#                                  1972         1973        1974        1975  \
# Country
# Aruba                             NaN          NaN         NaN         NaN
# Afghanistan              -12.52000000 -10.68000000 10.23000000 11.85000000
# Angola                    15.80000000  15.67000000 27.42000000 29.00000000
# Albania                           NaN          NaN         NaN         NaN
# United Arab Emirates      21.98000000  21.98000000 21.98000000 21.98000000
# ...                               ...          ...         ...         ...
# Saint Helena                      NaN          NaN         NaN         NaN
# Timor-Leste                       NaN          NaN         NaN         NaN
# Turks and Caicos Islands          NaN          NaN         NaN         NaN
# Somalia                           NaN          NaN         NaN         NaN
# Taiwan, China                     NaN          NaN         NaN         NaN
#
#                                 1976        1977  ...        2013       2014  \
# Country                                           ...
# Aruba                            NaN         NaN  ... -2.37000000 0.42000000
# Afghanistan               0.60000000  7.65000000  ...  7.39000000 4.67000000
# Angola                   80.70000000 69.01000000  ...  8.78000000 7.30000000
# Albania                          NaN         NaN  ...  1.93000000 1.62000000
# United Arab Emirates     21.98000000 21.97000000  ...  1.09000000 2.34000000
# ...                              ...         ...  ...         ...        ...
# Saint Helena                     NaN         NaN  ...  1.70000000 2.10000000
# Timor-Leste                      NaN         NaN  ... 10.99000000 0.85000000
# Turks and Caicos Islands         NaN         NaN  ...  2.50000000 2.30000000
# Somalia                          NaN         NaN  ...         NaN        NaN
# Taiwan, China                    NaN         NaN  ...  0.36000000 0.37000000
#
#                                 2015        2016        2017        2018  \
# Country
# Aruba                     0.48000000 -0.89000000 -0.47000000  3.58000000
# Afghanistan              -0.66000000  4.38000000  4.98000000  0.63000000
# Angola                    9.16000000 32.38000000 29.84000000 19.63000000
# Albania                   1.91000000  1.29000000  1.99000000  2.03000000
# United Arab Emirates      4.07000000  1.62000000  1.97000000  3.06000000
# ...                              ...         ...         ...         ...
# Saint Helena              1.90000000  2.60000000  5.10000000  3.80000000
# Timor-Leste               0.65000000 -1.47000000  0.52000000  2.29000000
# Turks and Caicos Islands  2.20000000  2.00000000  2.10000000  2.10000000
# Somalia                          NaN         NaN         NaN         NaN
# Taiwan, China             0.36000000  0.56000000  0.70000000  0.95000000
#
#                                 2019        2020        2021        2022
# Country
# Aruba                     4.26000000  1.22000000  0.74000000  6.04000000
# Afghanistan               2.30000000  5.44000000  5.06000000         NaN
# Angola                   17.08000000 21.02000000 23.85000000 21.35000000
# Albania                   1.41000000  1.62000000  2.04000000  6.73000000
# United Arab Emirates     -1.93000000 -2.08000000  0.18000000  5.22000000
# ...                              ...         ...         ...         ...
# Saint Helena              3.30000000  1.10000000  1.30000000         NaN
# Timor-Leste               0.96000000         NaN         NaN         NaN
# Turks and Caicos Islands  2.20000000  2.30000000         NaN         NaN
# Somalia                          NaN         NaN         NaN         NaN
# Taiwan, China             0.30000000  0.22000000  1.27000000  1.77000000
#
# [205 rows x 55 columns]

# %%
data.max()
# Out:
# index                     661
# Country Code              ZWE
# 1970              36.80000000
# 1971              71.30000000
# 1972              77.80000000
# 1973             352.81000000
# 1974             504.74000000
# 1975             374.74000000
# 1976             443.97000000
# 1977             176.00000000
# 1978             175.51000000
# 1979             159.51000000
# 1980             188.82000000
# 1981             116.80000000
# 1982             164.78000000
# 1983             343.81000000
# 1984            1289.54000000
# 1985           11702.83000000
# 1986             885.20000000
# 1987           13109.50000000
# 1988            4775.20000000
# 1989            7428.70000000
# 1990            7356.82000000
# 1991            2154.44000000
# 1992            4129.17000000
# 1993            4660.58000000
# 1994           23773.10000000
# 1995            2672.23000000
# 1996            4146.01000000
# 1997            1037.48000000
# 1998             107.43000000
# 1999             294.64000000
# 2000             550.00000000
# 2001             357.28000000
# 2002             108.89000000
# 2003              98.22000000
# 2004             113.57000000
# 2005              36.96000000
# 2006              53.25000000
# 2007              30.93000000
# 2008             156.96000000
# 2009              46.10000000
# 2010              28.17000000
# 2011              53.17000000
# 2012              59.50000000
# 2013              90.00000000
# 2014              62.14000000
# 2015             121.40000000
# 2016             379.85000000
# 2017             438.12000000
# 2018           65374.08000000
# 2019           19906.02000000
# 2020           17087.72000000
# 2021            1588.51000000
# 2022             284.94000000
# dtype: object

# %%
data['2018'].sort_values(ascending=False)
# Out:
# Country
# Venezuela, RB          65374.08000000
# South Sudan               83.49000000
# Sudan                     63.29000000
# Argentina                 34.28000000
# Congo, Dem. Rep.          29.27000000
#                             ...
# Eritrea                  -14.40000000
# Syrian Arab Republic              NaN
# Martinique                        NaN
# Niue                              NaN
# Somalia                           NaN
# Name: 2018, Length: 205, dtype: float64

# %%
data['1987'].sort_values(ascending=False)
# Out:
# Country
# Nicaragua                  13109.50000000
# Lebanon                      487.20000000
# Vietnam                      360.36000000
# Brazil                       228.34000000
# Uganda                       215.40000000
#                                 ...
# Niue                                  NaN
# Saint Helena                          NaN
# Timor-Leste                           NaN
# Turks and Caicos Islands              NaN
# Somalia                               NaN
# Name: 1987, Length: 205, dtype: float64

# %%
data.min()
# Out:
# index                     0
# Country Code            ABW
# 1970            -5.30000000
# 1971            -3.10000000
# 1972           -12.52000000
# 1973           -10.68000000
# 1974            -0.10000000
# 1975           -34.41000000
# 1976            -8.40000000
# 1977            -1.16000000
# 1978           -15.87000000
# 1979           -11.82000000
# 1980            -7.35000000
# 1981           -27.50000000
# 1982            -2.40000000
# 1983            -8.45000000
# 1984            -7.36000000
# 1985           -16.01000000
# 1986           -17.64000000
# 1987           -31.25000000
# 1988           -13.01000000
# 1989            -9.58000000
# 1990           -26.32000000
# 1991           -13.14000000
# 1992           -71.33000000
# 1993           -10.87000000
# 1994            -2.76000000
# 1995            -2.93000000
# 1996           -16.10000000
# 1997           -10.00000000
# 1998           -28.02000000
# 1999           -13.43000000
# 2000            -3.90000000
# 2001           -43.40000000
# 2002           -34.44000000
# 2003            -8.56000000
# 2004            -4.80000000
# 2005           -31.52000000
# 2006            -1.86000000
# 2007           -72.73000000
# 2008             1.03000000
# 2009            -6.81000000
# 2010            -3.90000000
# 2011            -3.37000000
# 2012            -3.05000000
# 2013            -2.37000000
# 2014            -1.41000000
# 2015            -3.75000000
# 2016            -3.09000000
# 2017           -13.31000000
# 2018           -14.40000000
# 2019           -16.36000000
# 2020            -2.60000000
# 2021            -3.01000000
# 2022             1.05000000
# dtype: object

# %%
data['2007'].sort_values()
# Out:
# Country
# Zimbabwe                 -72.73000000
# Chad                      -7.44000000
# Gabon                     -1.02000000
# Burkina Faso              -0.23000000
# Japan                      0.06000000
#                              ...
# British Virgin Islands            NaN
# Liechtenstein                     NaN
# Martinique                        NaN
# Niue                              NaN
# Somalia                           NaN
# Name: 2007, Length: 205, dtype: float64

# %%
mean = data.iloc[:, 2:].mean(numeric_only=True)
sns.set_style("whitegrid")
sns.lineplot(data=mean, color="blue", linewidth=2, marker="o", markersize=3, markerfacecolor="red")
plt.xticks(mean.index[::5])
plt.show(block=False)

# %%
column_to_clean = data.iloc[:, 1:]
column_to_clean, lower_quantile, upper_quantile = column_to_clean.align(lower_quantile, upper_quantile)

lower_quantile = column_to_clean.quantile(0.02, numeric_only=True)
upper_quantile = column_to_clean.quantile(0.98, numeric_only=True)

columns_cleaned = column_to_clean.mask((column_to_clean < lower_quantile) | (column_to_clean > upper_quantile), np.nan)
data_cleaned = pd.concat([data.drop(column_to_clean.columns, axis=1), columns_cleaned], axis=1)
data_cleaned.describe()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[92], line 2
#       1 column_to_clean = data.iloc[:, 1:]
# ----> 2 column_to_clean, lower_quantile, upper_quantile = column_to_clean.align(lower_quantile, upper_quantile)
#       4 lower_quantile = column_to_clean.quantile(0.02, numeric_only=True)
#       5 upper_quantile = column_to_clean.quantile(0.98, numeric_only=True)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5090, in DataFrame.align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#    5076 @doc(NDFrame.align, **_shared_doc_kwargs)
#    5077 def align(
#    5078     self,
#    (...)
#    5088     broadcast_axis: Axis | None = None,
#    5089 ) -> DataFrame:
# -> 5090     return super().align(
#    5091         other,
#    5092         join=join,
#    5093         axis=axis,
#    5094         level=level,
#    5095         copy=copy,
#    5096         fill_value=fill_value,
#    5097         method=method,
#    5098         limit=limit,
#    5099         fill_axis=fill_axis,
#    5100         broadcast_axis=broadcast_axis,
#    5101     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:9452, in NDFrame.align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#    9440     return self._align_frame(
#    9441         other,
#    9442         join=join,
#    (...)
#    9449         fill_axis=fill_axis,
#    9450     )
#    9451 elif isinstance(other, ABCSeries):
# -> 9452     return self._align_series(
#    9453         other,
#    9454         join=join,
#    9455         axis=axis,
#    9456         level=level,
#    9457         copy=copy,
#    9458         fill_value=fill_value,
#    9459         method=method,
#    9460         limit=limit,
#    9461         fill_axis=fill_axis,
#    9462     )
#    9463 else:  # pragma: no cover
#    9464     raise TypeError(f"unsupported type: {type(other)}")
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:9547, in NDFrame._align_series(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis)
#    9544 is_series = isinstance(self, ABCSeries)
#    9546 if (not is_series and axis is None) or axis not in [None, 0, 1]:
# -> 9547     raise ValueError("Must specify axis=0 or 1")
#    9549 if is_series and axis == 1:
#    9550     raise ValueError("cannot align series to a series other than axis 0")
#
# ValueError: Must specify axis=0 or 1

# %%
data_cleaned = data_cleaned.fillna(data_cleaned.mean(numeric_only=True))
data_cleaned
# Out:
#                           index Country Code        1970        1971  \
# Country
# Aruba                         0          ABW  5.71571429  5.83408163
# Afghanistan                   1          AFG  5.71571429  5.83408163
# Angola                        2          AGO  7.97000000  5.78000000
# Albania                       3          ALB  5.71571429  5.83408163
# United Arab Emirates          4          ARE 21.98000000 21.98000000
# ...                         ...          ...         ...         ...
# Saint Helena                200          SHN  5.71571429  5.83408163
# Timor-Leste                 201          TLS  5.71571429  5.83408163
# Turks and Caicos Islands    202          TCA  5.71571429  5.83408163
# Somalia                     648          SOM  5.71571429  5.83408163
# Taiwan, China               661          TWN  5.71571429  5.83408163
#
#                                 1972        1973        1974        1975  \
# Country
# Aruba                     6.97108844 11.83291391 18.39864865 14.46114865
# Afghanistan               6.97108844 11.83291391 10.23000000 11.85000000
# Angola                   15.80000000 15.67000000 27.42000000 29.00000000
# Albania                   6.97108844 11.83291391 18.39864865 14.46114865
# United Arab Emirates     21.98000000 21.98000000 21.98000000 21.98000000
# ...                              ...         ...         ...         ...
# Saint Helena              6.97108844 11.83291391 18.39864865 14.46114865
# Timor-Leste               6.97108844 11.83291391 18.39864865 14.46114865
# Turks and Caicos Islands  6.97108844 11.83291391 18.39864865 14.46114865
# Somalia                   6.97108844 11.83291391 18.39864865 14.46114865
# Taiwan, China             6.97108844 11.83291391 18.39864865 14.46114865
#
#                                 1976        1977  ...        2013       2014  \
# Country                                           ...
# Aruba                    11.42602740 13.52157534  ...  3.67572917 0.42000000
# Afghanistan               0.60000000  7.65000000  ...  7.39000000 4.67000000
# Angola                   11.42602740 69.01000000  ...  8.78000000 7.30000000
# Albania                  11.42602740 13.52157534  ...  1.93000000 1.62000000
# United Arab Emirates     21.98000000 21.97000000  ...  1.09000000 2.34000000
# ...                              ...         ...  ...         ...        ...
# Saint Helena             11.42602740 13.52157534  ...  1.70000000 2.10000000
# Timor-Leste              11.42602740 13.52157534  ... 10.99000000 0.85000000
# Turks and Caicos Islands 11.42602740 13.52157534  ...  2.50000000 2.30000000
# Somalia                  11.42602740 13.52157534  ...  3.67572917 3.25442708
# Taiwan, China            11.42602740 13.52157534  ...  0.36000000 0.37000000
#
#                                 2015        2016        2017        2018  \
# Country
# Aruba                     0.48000000 -0.89000000  4.17766839  3.58000000
# Afghanistan              -0.66000000  4.38000000  4.98000000  0.63000000
# Angola                    9.16000000  3.38598958 29.84000000 19.63000000
# Albania                   1.91000000  1.29000000  1.99000000  2.03000000
# United Arab Emirates      4.07000000  1.62000000  1.97000000  3.06000000
# ...                              ...         ...         ...         ...
# Saint Helena              1.90000000  2.60000000  5.10000000  3.80000000
# Timor-Leste               0.65000000 -1.47000000  0.52000000  2.29000000
# Turks and Caicos Islands  2.20000000  2.00000000  2.10000000  2.10000000
# Somalia                   3.04291667  3.38598958  4.17766839  3.77808290
# Taiwan, China             0.36000000  0.56000000  0.70000000  0.95000000
#
#                                 2019        2020        2021        2022
# Country
# Aruba                     4.26000000  1.22000000  0.74000000  6.04000000
# Afghanistan               2.30000000  5.44000000  5.06000000 10.73202186
# Angola                   17.08000000 21.02000000 23.85000000 21.35000000
# Albania                   1.41000000  1.62000000  2.04000000  6.73000000
# United Arab Emirates     -1.93000000  3.94240838  0.18000000  5.22000000
# ...                              ...         ...         ...         ...
# Saint Helena              3.30000000  1.10000000  1.30000000 10.73202186
# Timor-Leste               0.96000000  3.94240838  5.45210526 10.73202186
# Turks and Caicos Islands  2.20000000  2.30000000  5.45210526 10.73202186
# Somalia                   3.57196891  3.94240838  5.45210526 10.73202186
# Taiwan, China             0.30000000  0.22000000  1.27000000  1.77000000
#
# [205 rows x 55 columns]

# %%
data_cleaned.describe()
# Out:
#              index         1970         1971         1972         1973  \
# count 205.00000000 205.00000000 205.00000000 205.00000000 205.00000000
# mean  106.40000000   5.71571429   5.83408163   6.97108844  11.83291391
# std    79.94891751   4.13930822   4.48908095   4.77394790   7.40108117
# min     0.00000000  -0.86000000  -1.27000000  -3.60000000   0.00000000
# 25%    51.00000000   3.45000000   3.64000000   4.99000000   7.66000000
# 50%   102.00000000   5.71571429   5.83408163   6.97108844  11.83291391
# 75%   153.00000000   5.86000000   5.84000000   7.07000000  12.10000000
# max   661.00000000  22.26000000  23.95000000  26.86000000  61.25000000
#
#               1974         1975         1976         1977         1978  ...  \
# count 205.00000000 205.00000000 205.00000000 205.00000000 205.00000000  ...
# mean   18.39864865  14.46114865  11.42602740  13.52157534  11.27530612  ...
# std     8.69458163   7.35782887   8.77196590  10.00295724   8.79133588  ...
# min     0.10000000   0.10000000  -2.43000000   0.30000000  -1.58000000  ...
# 25%    13.52000000  10.13000000   7.04000000   8.35000000   6.69000000  ...
# 50%    18.39864865  14.46114865  11.42602740  13.52157534  11.14000000  ...
# 75%    20.03000000  16.77000000  11.42602740  13.52157534  11.27530612  ...
# max    55.00000000  49.43000000  56.08000000  69.01000000  50.55000000  ...
#
#               2013         2014         2015         2016         2017  \
# count 205.00000000 205.00000000 205.00000000 205.00000000 205.00000000
# mean    3.67572917   3.25442708   3.04291667   3.38598958   4.17766839
# std     3.04241543   3.28497556   4.08906658   4.80633274   5.23132395
# min    -0.51000000  -1.03000000  -2.10000000  -1.47000000  -0.22000000
# 25%     1.47000000   0.89000000   0.31000000   0.32000000   1.20000000
# 50%     2.78000000   2.56000000   1.89000000   1.92000000   2.43000000
# 75%     5.50000000   4.63000000   4.39000000   4.31000000   4.62000000
# max    18.33000000  18.09000000  26.00000000  25.88000000  30.40000000
#
#               2018         2019         2020         2021         2022
# count 205.00000000 205.00000000 205.00000000 205.00000000 205.00000000
# mean    3.77808290   3.57196891   3.94240838   5.45210526  10.73202186
# std     4.42882547   5.61941402   6.73886070   7.61324715   9.71836470
# min    -0.22000000  -2.09000000  -1.89000000  -0.23000000   1.77000000
# 25%     1.37000000   1.00000000   0.54000000   1.97000000   5.83000000
# 50%     2.51000000   2.31000000   2.44000000   3.62000000   8.40000000
# 75%     3.92000000   3.72000000   3.94240838   5.45210526  11.32000000
# max    29.27000000  50.99000000  49.77000000  59.11000000  72.43000000
#
# [8 rows x 54 columns]

# %%
data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 205 entries, Aruba to Taiwan, China
# Data columns (total 55 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         205 non-null    int64
#  1   Country Code  205 non-null    object
#  2   1970          205 non-null    float64
#  3   1971          205 non-null    float64
#  4   1972          205 non-null    float64
#  5   1973          205 non-null    float64
#  6   1974          205 non-null    float64
#  7   1975          205 non-null    float64
#  8   1976          205 non-null    float64
#  9   1977          205 non-null    float64
#  10  1978          205 non-null    float64
#  11  1979          205 non-null    float64
#  12  1980          205 non-null    float64
#  13  1981          205 non-null    float64
#  14  1982          205 non-null    float64
#  15  1983          205 non-null    float64
#  16  1984          205 non-null    float64
#  17  1985          205 non-null    float64
#  18  1986          205 non-null    float64
#  19  1987          205 non-null    float64
#  20  1988          205 non-null    float64
#  21  1989          205 non-null    float64
#  22  1990          205 non-null    float64
#  23  1991          205 non-null    float64
#  24  1992          205 non-null    float64
#  25  1993          205 non-null    float64
#  26  1994          205 non-null    float64
#  27  1995          205 non-null    float64
#  28  1996          205 non-null    float64
#  29  1997          205 non-null    float64
#  30  1998          205 non-null    float64
#  31  1999          205 non-null    float64
#  32  2000          205 non-null    float64
#  33  2001          205 non-null    float64
#  34  2002          205 non-null    float64
#  35  2003          205 non-null    float64
#  36  2004          205 non-null    float64
#  37  2005          205 non-null    float64
#  38  2006          205 non-null    float64
#  39  2007          205 non-null    float64
#  40  2008          205 non-null    float64
#  41  2009          205 non-null    float64
#  42  2010          205 non-null    float64
#  43  2011          205 non-null    float64
#  44  2012          205 non-null    float64
#  45  2013          205 non-null    float64
#  46  2014          205 non-null    float64
#  47  2015          205 non-null    float64
#  48  2016          205 non-null    float64
#  49  2017          205 non-null    float64
#  50  2018          205 non-null    float64
#  51  2019          205 non-null    float64
#  52  2020          205 non-null    float64
#  53  2021          205 non-null    float64
#  54  2022          205 non-null    float64
# dtypes: float64(53), int64(1), object(1)
# memory usage: 89.7+ KB

# %%
data_cleaned['2018'].sort_values(ascending=False)
# Out:
# Country
# Congo, Dem. Rep.     29.27000000
# Yemen, Rep.          27.60000000
# Liberia              23.56000000
# Angola               19.63000000
# Iran, Islamic Rep.   17.95000000
#                          ...
# Qatar                 0.22000000
# Brunei Darussalam     0.15000000
# Djibouti              0.15000000
# West Bank and Gaza   -0.20000000
# Ecuador              -0.22000000
# Name: 2018, Length: 205, dtype: float64

# %%
data_cleaned.max()
# Out:
# index                    661
# Country Code             ZWE
# 1970             22.26000000
# 1971             23.95000000
# 1972             26.86000000
# 1973             61.25000000
# 1974             55.00000000
# 1975             49.43000000
# 1976             56.08000000
# 1977             69.01000000
# 1978             50.55000000
# 1979             78.31000000
# 1980             94.26000000
# 1981            100.00000000
# 1982            100.54000000
# 1983            135.03000000
# 1984            141.30000000
# 1985            225.99000000
# 1986            143.80000000
# 1987            215.40000000
# 1988            342.95000000
# 1989           1281.44000000
# 1990            600.00000000
# 1991            216.40000000
# 1992           1243.00000000
# 1993           2600.72000000
# 1994           2075.89000000
# 1995            541.80000000
# 1996            125.53000000
# 1997             87.96000000
# 1998             59.01000000
# 1999             85.75000000
# 2000             70.00000000
# 2001             54.40000000
# 2002             42.65000000
# 2003             28.49000000
# 2004             27.00000000
# 2005             18.36000000
# 2006             23.08000000
# 2007             18.55000000
# 2008             30.37000000
# 2009             22.42000000
# 2010             13.74000000
# 2011             21.35000000
# 2012             30.57000000
# 2013             18.33000000
# 2014             18.09000000
# 2015             26.00000000
# 2016             25.88000000
# 2017             30.40000000
# 2018             29.27000000
# 2019             50.99000000
# 2020             49.77000000
# 2021             59.11000000
# 2022             72.43000000
# dtype: object

# %%
data_cleaned['1993'].sort_values(ascending=False)
# Out:
# Country
# Tajikistan         2600.72000000
# Congo, Dem. Rep.   1986.90000000
# Brazil             1927.38000000
# Kazakhstan         1662.28000000
# Croatia            1523.68000000
#                         ...
# Niger                -0.33000000
# Seychelles           -0.34000000
# Mali                 -0.57000000
# Senegal              -0.74000000
# Qatar                -0.86000000
# Name: 1993, Length: 205, dtype: float64

# %%
mean2 = data_cleaned.iloc[:, 2:].mean(numeric_only=True)
sns.set_style("darkgrid")
sns.lineplot(data=mean2, color="blue", linewidth=2, label="clean inflation")
sns.lineplot(data=mean, color="red", linewidth=2, label="inflation")
plt.xticks(mean2.index[::5])
plt.legend()
plt.show(block=False)

# %%
top_data = data.mean(axis=1, numeric_only=True).sort_values(ascending=False).head(10).sort_values(ascending=True)
top_data_cleaned = data_cleaned.mean(axis=1, numeric_only=True).sort_values(ascending=False).head(10).sort_values(ascending=True)
low_data = data.mean(axis=1, numeric_only=True).sort_values().head(10)
low_data_cleaned = data_cleaned.mean(axis=1, numeric_only=True).sort_values().head(10)

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 8))

axs[0, 0].barh(top_data.index, top_data.values, color='blue')
axs[0, 0].set_title('10 countries with the highest average inflation rate (raw data)')

axs[0, 1].barh(top_data_cleaned.index, top_data_cleaned.values, color='green')
axs[0, 1].set_title('10 countries with the highest average inflation rate (cleaned data)')

axs[1, 0].barh(low_data.index, low_data.values, color='red')
axs[1, 0].set_title('10 countries with the lowest average inflation rate (raw data)')

axs[1, 1].barh(low_data_cleaned.index, low_data_cleaned.values, color='orange')
axs[1, 1].set_title('10 countries with the lowest average inflation rate (cleaned data)')

plt.tight_layout()

plt.show(block=False)

# %%
population_raw = pd.read_csv("C:\PytonDataSets\world_population.csv", encoding='cp1252')
population_raw.head()
# Out:
#    Rank CCA3 Country/Territory           Capital Continent  2022 Population  \
# 0    36  AFG       Afghanistan             Kabul      Asia         41128771
# 1   138  ALB           Albania            Tirana    Europe          2842321
# 2    34  DZA           Algeria           Algiers    Africa         44903225
# 3   213  ASM    American Samoa         Pago Pago   Oceania            44273
# 4   203  AND           Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (kmÂ²)  \
# 0         10694796         12486631         10752971       652230
# 1          3295066          2941651          2324731        28748
# 2         25518074         18739378         13795915      2381741
# 3            47818            32886            27075          199
# 4            53569            35611            19860          468
#
#    Density (per kmÂ²)  Growth Rate  World Population Percentage
# 0         63.05870000   1.02570000                   0.52000000
# 1         98.87020000   0.99570000                   0.04000000
# 2         18.85310000   1.01640000                   0.56000000
# 3        222.47740000   0.98310000                   0.00000000
# 4        170.56410000   1.01000000                   0.00000000

# %%
population_raw = population_raw[["CCA3", "2022 Population"]]
print(population_raw["2022 Population"].isna().sum())
print(len(population_raw["CCA3"].unique()))
# Out:
# 0
# 234

# %%
data_cleaned['Country Code'].isin(population_raw["CCA3"]).sort_values()
# Out:
# Country
# Saint Helena            False
# Kosovo                  False
# Aruba                    True
# Netherlands              True
# Norway                   True
#                         ...
# Guatemala                True
# Guyana                   True
# Hong Kong SAR, China     True
# Georgia                  True
# Taiwan, China            True
# Name: Country Code, Length: 205, dtype: bool

# %%
data_cleaned = data_cleaned.drop(index=['Saint Helena', 'Kosovo'])

# %%
population_raw = population_raw.rename(columns={'CCA3': 'Country Code'})

# %%
merged = data_cleaned.merge(population_raw, on='Country Code', how='left')
merged.set_index(data_cleaned.index, inplace=True)

# %%
total_population = merged['2022 Population'].sum()
merged['Population Ratio'] = merged['2022 Population'] / total_population
merged['Population Ratio'] = merged['Population Ratio']
merged
# Out:
#                           index Country Code        1970        1971  \
# Country
# Aruba                         0          ABW  5.71571429  5.83408163
# Afghanistan                   1          AFG  5.71571429  5.83408163
# Angola                        2          AGO  7.97000000  5.78000000
# Albania                       3          ALB  5.71571429  5.83408163
# United Arab Emirates          4          ARE 21.98000000 21.98000000
# ...                         ...          ...         ...         ...
# Niue                        199          NIU  5.71571429  5.83408163
# Timor-Leste                 201          TLS  5.71571429  5.83408163
# Turks and Caicos Islands    202          TCA  5.71571429  5.83408163
# Somalia                     648          SOM  5.71571429  5.83408163
# Taiwan, China               661          TWN  5.71571429  5.83408163
#
#                                 1972        1973        1974        1975  \
# Country
# Aruba                     6.97108844 11.83291391 18.39864865 14.46114865
# Afghanistan               6.97108844 11.83291391 10.23000000 11.85000000
# Angola                   15.80000000 15.67000000 27.42000000 29.00000000
# Albania                   6.97108844 11.83291391 18.39864865 14.46114865
# United Arab Emirates     21.98000000 21.98000000 21.98000000 21.98000000
# ...                              ...         ...         ...         ...
# Niue                      6.97108844 11.83291391 18.39864865 14.46114865
# Timor-Leste               6.97108844 11.83291391 18.39864865 14.46114865
# Turks and Caicos Islands  6.97108844 11.83291391 18.39864865 14.46114865
# Somalia                   6.97108844 11.83291391 18.39864865 14.46114865
# Taiwan, China             6.97108844 11.83291391 18.39864865 14.46114865
#
#                                 1976        1977  ...        2015        2016  \
# Country                                           ...
# Aruba                    11.42602740 13.52157534  ...  0.48000000 -0.89000000
# Afghanistan               0.60000000  7.65000000  ... -0.66000000  4.38000000
# Angola                   11.42602740 69.01000000  ...  9.16000000  3.38598958
# Albania                  11.42602740 13.52157534  ...  1.91000000  1.29000000
# United Arab Emirates     21.98000000 21.97000000  ...  4.07000000  1.62000000
# ...                              ...         ...  ...         ...         ...
# Niue                     11.42602740 13.52157534  ...  3.04291667  3.38598958
# Timor-Leste              11.42602740 13.52157534  ...  0.65000000 -1.47000000
# Turks and Caicos Islands 11.42602740 13.52157534  ...  2.20000000  2.00000000
# Somalia                  11.42602740 13.52157534  ...  3.04291667  3.38598958
# Taiwan, China            11.42602740 13.52157534  ...  0.36000000  0.56000000
#
#                                 2017        2018        2019        2020  \
# Country
# Aruba                     4.17766839  3.58000000  4.26000000  1.22000000
# Afghanistan               4.98000000  0.63000000  2.30000000  5.44000000
# Angola                   29.84000000 19.63000000 17.08000000 21.02000000
# Albania                   1.99000000  2.03000000  1.41000000  1.62000000
# United Arab Emirates      1.97000000  3.06000000 -1.93000000  3.94240838
# ...                              ...         ...         ...         ...
# Niue                      4.17766839  3.77808290  3.57196891  3.94240838
# Timor-Leste               0.52000000  2.29000000  0.96000000  3.94240838
# Turks and Caicos Islands  2.10000000  2.10000000  2.20000000  2.30000000
# Somalia                   4.17766839  3.77808290  3.57196891  3.94240838
# Taiwan, China             0.70000000  0.95000000  0.30000000  0.22000000
#
#                                 2021        2022  2022 Population  \
# Country
# Aruba                     0.74000000  6.04000000           106445
# Afghanistan               5.06000000 10.73202186         41128771
# Angola                   23.85000000 21.35000000         35588987
# Albania                   2.04000000  6.73000000          2842321
# United Arab Emirates      0.18000000  5.22000000          9441129
# ...                              ...         ...              ...
# Niue                      5.45210526 10.73202186             1934
# Timor-Leste               5.45210526 10.73202186          1341296
# Turks and Caicos Islands  5.45210526 10.73202186            45703
# Somalia                   5.45210526 10.73202186         17597511
# Taiwan, China             1.27000000  1.77000000         23893394
#
#                           Population Ratio
# Country
# Aruba                           0.00001342
# Afghanistan                     0.00518507
# Angola                          0.00448667
# Albania                         0.00035833
# United Arab Emirates            0.00119023
# ...                                    ...
# Niue                            0.00000024
# Timor-Leste                     0.00016910
# Turks and Caicos Islands        0.00000576
# Somalia                         0.00221850
# Taiwan, China                   0.00301222
#
# [203 rows x 57 columns]

# %%
for index in range(2, 55):
    merged.iloc[:, index] =  merged.iloc[:, index] * merged["Population Ratio"]
    
merged
# Out:
#                           index Country Code       1970       1971       1972  \
# Country
# Aruba                         0          ABW 0.00007670 0.00007829 0.00009355
# Afghanistan                   1          AFG 0.02963636 0.03025010 0.03614556
# Angola                        2          AGO 0.03575877 0.02593296 0.07088940
# Albania                       3          ALB 0.00204811 0.00209052 0.00249794
# United Arab Emirates          4          ARE 0.02616135 0.02616135 0.02616135
# ...                         ...          ...        ...        ...        ...
# Niue                        199          NIU 0.00000139 0.00000142 0.00000170
# Timor-Leste                 201          TLS 0.00096650 0.00098652 0.00117878
# Turks and Caicos Islands    202          TCA 0.00003293 0.00003361 0.00004017
# Somalia                     648          SOM 0.01268032 0.01294292 0.01546537
# Taiwan, China               661          TWN 0.01721698 0.01757353 0.02099844
#
#                                1973       1974       1975       1976  \
# Country
# Aruba                    0.00015879 0.00024690 0.00019406 0.00015333
# Afghanistan              0.06135444 0.05304323 0.06144304 0.00311104
# Angola                   0.07030613 0.12302452 0.13011346 0.05126482
# Albania                  0.00424007 0.00659277 0.00518185 0.00409427
# United Arab Emirates     0.02616135 0.02616135 0.02616135 0.02616135
# ...                             ...        ...        ...        ...
# Niue                     0.00000289 0.00000449 0.00000353 0.00000279
# Timor-Leste              0.00200090 0.00311114 0.00244532 0.00193210
# Turks and Caicos Islands 0.00006818 0.00010601 0.00008332 0.00006583
# Somalia                  0.02625134 0.04081744 0.03208209 0.02534867
# Taiwan, China            0.03564332 0.05542075 0.04356014 0.03441769
#
#                                1977  ...        2015        2016       2017  \
# Country                              ...
# Aruba                    0.00018145  ...  0.00000644 -0.00001194 0.00005606
# Afghanistan              0.03966576  ... -0.00342214  0.02271059 0.02582163
# Angola                   0.30962516  ...  0.04109791  0.01519182 0.13388226
# Albania                  0.00484517  ...  0.00068441  0.00046224 0.00071307
# United Arab Emirates     0.02614945  ...  0.00484425  0.00192818 0.00234476
# ...                             ...  ...         ...         ...        ...
# Niue                     0.00000330  ...  0.00000074  0.00000083 0.00000102
# Timor-Leste              0.00228644  ...  0.00010991 -0.00024857 0.00008793
# Turks and Caicos Islands 0.00007791  ...  0.00001268  0.00001152 0.00001210
# Somalia                  0.02999764  ...  0.00675072  0.00751182 0.00926817
# Taiwan, China            0.04072994  ...  0.00108440  0.00168684 0.00210855
#
#                                2018        2019       2020       2021  \
# Country
# Aruba                    0.00004804  0.00005717 0.00001637 0.00000993
# Afghanistan              0.00326659  0.01192565 0.02820676 0.02623644
# Angola                   0.08807335  0.07663234 0.09430982 0.10700710
# Albania                  0.00072741  0.00050524 0.00058049 0.00073099
# United Arab Emirates     0.00364212 -0.00229715 0.00469239 0.00021424
# ...                             ...         ...        ...        ...
# Niue                     0.00000092  0.00000087 0.00000096 0.00000133
# Timor-Leste              0.00038723  0.00016233 0.00066665 0.00092193
# Turks and Caicos Islands 0.00001210  0.00001268 0.00001325 0.00003141
# Somalia                  0.00838168  0.00792442 0.00874624 0.01209551
# Taiwan, China            0.00286161  0.00090367 0.00066269 0.00382552
#
#                                2022  2022 Population  Population Ratio
# Country
# Aruba                    0.00008105           106445        0.00001342
# Afghanistan              0.05564625         41128771        0.00518507
# Angola                   0.09579042         35588987        0.00448667
# Albania                  0.00241155          2842321        0.00035833
# United Arab Emirates     0.00621302          9441129        0.00119023
# ...                             ...              ...               ...
# Niue                     0.00000262             1934        0.00000024
# Timor-Leste              0.00181474          1341296        0.00016910
# Turks and Caicos Islands 0.00006184            45703        0.00000576
# Somalia                  0.02380901         17597511        0.00221850
# Taiwan, China            0.00533163         23893394        0.00301222
#
# [203 rows x 57 columns]

# %%
mean3 = merged.iloc[:, 2:55].sum()

fig, axes = plt.subplots(1, 3, figsize=(8, 5))

sns.boxplot(data=mean3, color='blue', ax=axes[0])
axes[0].set_title('Pupolation Ratio Mean Boxplot')

sns.boxplot(data=mean2, color='red', ax=axes[1])
axes[1].set_title('Cleaned Mean Boxplot')

sns.boxplot(data=mean, color='green', ax=axes[2])
axes[2].set_title('Raw Mean Boxplot')

plt.subplots_adjust(wspace=0.5)

plt.tight_layout()
plt.show()

# %%
sns.set_style("ticks")

colors = ["blue", "red", "green"]

linewidth = 1

sns.lineplot(data=mean2, color=colors[0], linewidth=linewidth, label="clean inflation", alpha = 0.5)

sns.lineplot(data=mean, color=colors[1], linewidth=linewidth, label="inflation")

sns.lineplot(data=mean3, color=colors[2], linewidth=linewidth, label="weighted inflation", alpha = 0.5)

plt.xlabel("Year")
plt.ylabel("Inflation")
plt.legend()

plt.xticks(mean2.index[::5])

plt.show(block=False)
